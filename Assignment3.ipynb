# %% [markdown]
# <a href="https://colab.research.google.com/github/thien5919/AppliedDataScience/blob/COMP3122/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Duc Thien Tran
#
# # Student ID: 101333237

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Question 1

# %%
import pandas as pd

# %%
myDF = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment3/test.csv')

# %% [markdown]
# Question 2

# %%
myDF.head()
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50    F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21    M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America
# 3  40    156     44    Q   RHRHJY  IR14  [89$]           Asia
# 4  50    468     33    J   HPQCMC  QX90  [95$]         Africa

# %% [markdown]
# Question 3

# %%
myDF.rename(columns={'Type': "Machine Type", 'Zip Code': 'Zip code'}, inplace= True)

# %%
myDF.head(1)
# Out:
#    ID  Range  Value Machine Type Zip code Model   Cost Continent
# 0  10    192     50            F   NXEYEM  EX85  [56$]      Asia

# %%
new_row={'ID': 'ID', 'Range': 'Range', 'Value': 'Value', 'Type': 'Machine Type', 'Zip Code': 'Zip code'}
name_row= {'ID': 'Name', 'Range': "Duc Thien Tran"}
id_row= {'ID': 'Student ID', 'Range': "101333237"}
myDF = pd.concat([pd.DataFrame([name_row, id_row, new_row]), myDF], ignore_index=True, copy= False)
myDF.head()
# Out:
#            ID           Range  Value          Type  Zip Code Machine Type  \
# 0        Name  Duc Thien Tran    NaN           NaN       NaN          NaN
# 1  Student ID       101333237    NaN           NaN       NaN          NaN
# 2          ID           Range  Value  Machine Type  Zip code          NaN
# 3          10             192     50           NaN       NaN            F
# 4          20             299     21           NaN       NaN            M
#
#   Zip code Model   Cost Continent
# 0      NaN   NaN    NaN       NaN
# 1      NaN   NaN    NaN       NaN
# 2      NaN   NaN    NaN       NaN
# 3   NXEYEM  EX85  [56$]      Asia
# 4   VNFKZD  CT41  [18$]      Asia

# %% [markdown]
# Question 6

# %%
type(myDF)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Question 7

# %%
myDF['Value']
# Out:
# 0      50
# 1      21
# 2      28
# 3      44
# 4      33
#        ..
# 945    12
# 946    46
# 947    46
# 948    13
# 949    10
# Name: Value, Length: 950, dtype: int64

# %%
myDF.loc[:, ['Value']]
# Out:
#      Value
# 0       50
# 1       21
# 2       28
# 3       44
# 4       33
# ..     ...
# 945     12
# 946     46
# 947     46
# 948     13
# 949     10
#
# [950 rows x 1 columns]

# %% [markdown]
# Question 8

# %%
myDF['Value'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Question 9

# %%
myDF['Zip code']
# Out:
# 0      NXEYEM
# 1      VNFKZD
# 2      IMGMFY
# 3      RHRHJY
# 4      HPQCMC
#         ...
# 945    HGVBPV
# 946    SHBAUD
# 947    PUZUVO
# 948    UMESZO
# 949    JOHHVL
# Name: Zip code, Length: 950, dtype: object

# %%
myDF.loc[:, ['Zip code']]
# Out:
#     Zip code
# 0     NXEYEM
# 1     VNFKZD
# 2     IMGMFY
# 3     RHRHJY
# 4     HPQCMC
# ..       ...
# 945   HGVBPV
# 946   SHBAUD
# 947   PUZUVO
# 948   UMESZO
# 949   JOHHVL
#
# [950 rows x 1 columns]

# %% [markdown]
# Question 10

# %%
myDF['Brand'] = myDF['Machine Type'] + myDF['Zip code']
myDF['Brand'].head
# Out:
# <bound method NDFrame.head of 0      FNXEYEM
# 1      MVNFKZD
# 2      XIMGMFY
# 3      QRHRHJY
# 4      JHPQCMC
#         ...
# 945    CHGVBPV
# 946    LSHBAUD
# 947    KPUZUVO
# 948    NUMESZO
# 949    WJOHHVL
# Name: Brand, Length: 950, dtype: object>

# %% [markdown]
# Question 11

# %%
myDF['Total']= myDF['Range'] * myDF['Value']
myDF['Total'].head
# Out:
# <bound method NDFrame.head of 0       9600
# 1       6279
# 2      10584
# 3       6864
# 4      15444
#        ...
# 945     1632
# 946    14536
# 947    21206
# 948     2405
# 949     1370
# Name: Total, Length: 950, dtype: int64>

# %% [markdown]
# Question 12
# The parentheses mean a call for a method in python. For example, myDF.head() is a method calls to call head() method to display the first 5 rows (default) and myDF.describe() is called to generate summary statistics for the DataFrame . Whereas, the rest of commands are used to access attribute to display information such as myDF.describe to show informatiton about this method myDF.shape() provides dimensions of DataFrame (rows and columns) and myDF.dtype() shows the types of each column in the DataFrame

# %%
myDF.head()
# Out:
#    ID  Range  Value Machine Type Zip code Model   Cost      Continent  \
# 0  10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28            X   IMGMFY  VN81  [90$]  North America
# 3  40    156     44            Q   RHRHJY  IR14  [89$]           Asia
# 4  50    468     33            J   HPQCMC  QX90  [95$]         Africa
#
#               new
# 0  Duc Thien Tran
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
myDF.describe()
# Out:
#                 id       range       value         total
# count   948.000000  948.000000  948.000000    948.000000
# mean   4764.926160  297.534810   29.919831   8963.758439
# std    2738.210997  115.848424   12.268981   5264.606947
# min      10.000000  100.000000   10.000000   1090.000000
# 25%    2397.500000  194.000000   19.000000   4859.250000
# 50%    4765.000000  296.000000   30.000000   7916.000000
# 75%    7132.500000  399.250000   41.000000  12365.250000
# max    9500.000000  500.000000   50.000000  24750.000000

# %%
myDF.describe
# Out:
# <bound method NDFrame.describe of        id  range  value machine type zip code Model   Cost      Continent  \
# 949  9500    137     10            W   JOHHVL  QE45  [10$]  South America
# 815  8160    109     10            B   INKSSV  UG93  [58$]         Europe
# 506  5070    268     10            N   WHIZNL  LX38  [22$]  South America
# 888  8890    430     10            Q   VXHFZN  BW49  [35$]     Antarctica
# 538  5390    350     10            J   WEUVDY  CN38  [26$]           Asia
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 354  3550    160     50            M   SBSWYH  AE26  [18$]  South America
# 883  8840    385     50            F   UBWOJQ  BE92  [39$]  North America
# 805  8060    136     50            C   MLHIBG  GD59  [91$]           Asia
# 795  7960    448     50            B   GIYNZN  LC10  [82$]     Antarctica
# 0      10    192     50            F   NXEYEM  EX85  [56$]           Asia
#
#        brand  total
# 949  WJOHHVL   1370
# ...

# %%
myDF.shape
# Out:
# (948, 10)

# %%
myDF.dtypes
# Out:
# id               int64
# range            int64
# value            int64
# machine type    object
# zip code        object
# Model           object
# Cost            object
# Continent       object
# brand           object
# total            int64
# dtype: object

# %% [markdown]
# Question 13

# %%
myDF.describe(include='all')
# Out:
#                  ID       Range       Value Machine Type Zip code Model  \
# count    950.000000  950.000000  950.000000          948      941   950
# unique          NaN         NaN         NaN           26      941   946
# top             NaN         NaN         NaN            F   NXEYEM  MS98
# freq            NaN         NaN         NaN           50        1     2
# mean    4755.000000  297.437895   29.943158          NaN      NaN   NaN
# std     2743.856775  115.828540   12.267347          NaN      NaN   NaN
# min       10.000000  100.000000   10.000000          NaN      NaN   NaN
# 25%     2382.500000  194.000000   19.000000          NaN      NaN   NaN
# 50%     4755.000000  296.000000   30.000000          NaN      NaN   NaN
# 75%     7127.500000  398.750000   41.000000          NaN      NaN   NaN
# max     9500.000000  500.000000   50.000000          NaN      NaN   NaN
#
#          Cost      Continent    Brand         Total
# ...

# %% [markdown]
# Question 14

# %%
myDF.rename(columns={"ID": "My ID"}).head()
# Out:
#    My ID  Range  Value Machine Type Zip code Model   Cost      Continent  \
# 0     10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1     20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2     30    378     28            X   IMGMFY  VN81  [90$]  North America
# 3     40    156     44            Q   RHRHJY  IR14  [89$]           Asia
# 4     50    468     33            J   HPQCMC  QX90  [95$]         Africa
#
#      Brand  Total
# 0  FNXEYEM   9600
# 1  MVNFKZD   6279
# 2  XIMGMFY  10584
# 3  QRHRHJY   6864
# 4  JHPQCMC  15444

# %% [markdown]
# Question 15

# %%
myDF.rename(columns={"ID": "My ID"}, inplace= True)
myDF.head()
# Out:
#    My ID  Range  Value Machine Type Zip code Model   Cost      Continent  \
# 0     10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1     20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2     30    378     28            X   IMGMFY  VN81  [90$]  North America
# 3     40    156     44            Q   RHRHJY  IR14  [89$]           Asia
# 4     50    468     33            J   HPQCMC  QX90  [95$]         Africa
#
#      Brand  Total
# 0  FNXEYEM   9600
# 1  MVNFKZD   6279
# 2  XIMGMFY  10584
# 3  QRHRHJY   6864
# 4  JHPQCMC  15444

# %% [markdown]
# Question 16

# %%
myDF.columns
# Out:
# Index(['My ID', 'Range', 'Value', 'Machine Type', 'Zip code', 'Model', 'Cost',
#        'Continent', 'Brand', 'Total'],
#       dtype='object')

# %% [markdown]
# Question 17

# %%
myDF.rename(columns= {'My ID':'id', 'Range':'range', 'Value':'value', 'Machine Type':'machine type', 'Zip code':'zip code', 'Brand':'brand', 'Total':'total'}, inplace= True)

# %%
myDF.head()
# Out:
#    id  range  value machine type zip code Model   Cost      Continent  \
# 0  10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28            X   IMGMFY  VN81  [90$]  North America
# 3  40    156     44            Q   RHRHJY  IR14  [89$]           Asia
# 4  50    468     33            J   HPQCMC  QX90  [95$]         Africa
#
#      brand  total
# 0  FNXEYEM   9600
# 1  MVNFKZD   6279
# 2  XIMGMFY  10584
# 3  QRHRHJY   6864
# 4  JHPQCMC  15444

# %% [markdown]
# Question 18

# %%
myDF.columns = myDF.columns.str.replace(" ", "_")
myDF.head()
# Out:
#    My_ID  Range  Value Machine_Type Zip_code Model   Cost      Continent  \
# 0     10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1     20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2     30    378     28            X   IMGMFY  VN81  [90$]  North America
# 3     40    156     44            Q   RHRHJY  IR14  [89$]           Asia
# 4     50    468     33            J   HPQCMC  QX90  [95$]         Africa
#
#      Brand  Total
# 0  FNXEYEM   9600
# 1  MVNFKZD   6279
# 2  XIMGMFY  10584
# 3  QRHRHJY   6864
# 4  JHPQCMC  15444

# %% [markdown]
# Question 19

# %%
myDF.drop(['brand', 'total'], axis=1, inplace=False)
# Out:
#        id  range  value machine type zip code Model   Cost      Continent
# 0      10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1      20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2      30    378     28            X   IMGMFY  VN81  [90$]  North America
# 3      40    156     44            Q   RHRHJY  IR14  [89$]           Asia
# 4      50    468     33            J   HPQCMC  QX90  [95$]         Africa
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 945  9460    136     12            C   HGVBPV  NG88  [51$]  South America
# 946  9470    316     46            L   SHBAUD  IE12  [33$]  North America
# 947  9480    461     46            K   PUZUVO  HB82  [12$]         Europe
# 948  9490    185     13            N   UMESZO  WJ90  [39$]  North America
# 949  9500    137     10            W   JOHHVL  QE45  [10$]  South America
#
# [950 rows x 8 columns]

# %% [markdown]
# Question 20

# %%
myDF.drop([3,5],axis=0,inplace=True)
myDF.head()
# Out:
#    id  range  value machine type zip code Model   Cost      Continent  \
# 0  10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28            X   IMGMFY  VN81  [90$]  North America
# 4  50    468     33            J   HPQCMC  QX90  [95$]         Africa
# 6  70    327     24            F   NLVQPY  JY72  [25$]         Europe
#
#      brand  total
# 0  FNXEYEM   9600
# 1  MVNFKZD   6279
# 2  XIMGMFY  10584
# 4  JHPQCMC  15444
# 6  FNLVQPY   7848

# %% [markdown]
# Question 21

# %%
myDF.value.sort_values(ascending=True)
# Out:
# 949    10
# 506    10
# 888    10
# 203    10
# 538    10
#        ..
# 310    50
# 306    50
# 670    50
# 559    50
# 0      50
# Name: value, Length: 948, dtype: int64

# %% [markdown]
# Question 22

# %%
myDF.sort_values(by=['value'],ascending=True)
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 949  9500    137     10            W   JOHHVL  QE45  [10$]  South America
# 506  5070    268     10            N   WHIZNL  LX38  [22$]  South America
# 888  8890    430     10            Q   VXHFZN  BW49  [35$]     Antarctica
# 203  2040    148     10            T   NRLBSZ  WJ22  [30$]           Asia
# 538  5390    350     10            J   WEUVDY  CN38  [26$]           Asia
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 310  3110    203     50            G   ZQJXWY  LH16  [35$]      Australia
# 306  3070    315     50            D   VFJBWF  DB57  [68$]         Europe
# 670  6710    191     50            A   QSURZT  FK58  [87$]           Asia
# 559  5600    395     50            T   CVSBMG  MK75  [41$]  North America
# 0      10    192     50            F   NXEYEM  EX85  [56$]           Asia
#
#        brand  total
# 949  WJOHHVL   1370
# 506  NWHIZNL   2680
# ...

# %%
myDF.head()
# Out:
#    id  range  value machine type zip code Model   Cost      Continent  \
# 0  10    192     50            F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21            M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28            X   IMGMFY  VN81  [90$]  North America
# 4  50    468     33            J   HPQCMC  QX90  [95$]         Africa
# 6  70    327     24            F   NLVQPY  JY72  [25$]         Europe
#
#      brand  total
# 0  FNXEYEM   9600
# 1  MVNFKZD   6279
# 2  XIMGMFY  10584
# 4  JHPQCMC  15444
# 6  FNLVQPY   7848

# %% [markdown]
# Question 23

# %%
myDF.sort_values(by=['value'],ascending=True,inplace=True)
myDF.head()
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 949  9500    137     10            W   JOHHVL  QE45  [10$]  South America
# 815  8160    109     10            B   INKSSV  UG93  [58$]         Europe
# 506  5070    268     10            N   WHIZNL  LX38  [22$]  South America
# 888  8890    430     10            Q   VXHFZN  BW49  [35$]     Antarctica
# 538  5390    350     10            J   WEUVDY  CN38  [26$]           Asia
#
#        brand  total
# 949  WJOHHVL   1370
# 815  BINKSSV   1090
# 506  NWHIZNL   2680
# 888  QVXHFZN   4300
# 538  JWEUVDY   3500

# %% [markdown]
# Question 24

# %%
myDF.sort_values(by=['range','value'],ascending=[True,False])
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 504  5050    100     21            S   KLYYQV  NF53  [92$]         Africa
# 462  4630    101     26            P   PBJHPM  JI69  [38$]         Europe
# 798  7990    101     20            E   QXAZJW  UG28  [53$]         Africa
# 556  5570    102     15            M   SSGQYR  US97  [54$]         Africa
# 751  7520    103     44            Q   XOGVUH  FY52  [80$]         Africa
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 178  1790    499     25            F   KOJGHA  DB52  [73$]  South America
# 163  1640    499     13            M   JQQXBS  DD63  [15$]           Asia
# 411  4120    500     27            Q   NRNLPN  LW95  [25$]         Europe
# 731  7320    500     20            Z   JUKAMV  NV42  [34$]  North America
# 423  4240    500     17            Q   IYUYPO  EG71  [95$]         Europe
#
#        brand  total
# 504  SKLYYQV   2100
# 462  PPBJHPM   2626
# ...

# %%
myDF.head()
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 949  9500    137     10            W   JOHHVL  QE45  [10$]  South America
# 815  8160    109     10            B   INKSSV  UG93  [58$]         Europe
# 506  5070    268     10            N   WHIZNL  LX38  [22$]  South America
# 888  8890    430     10            Q   VXHFZN  BW49  [35$]     Antarctica
# 538  5390    350     10            J   WEUVDY  CN38  [26$]           Asia
#
#        brand  total
# 949  WJOHHVL   1370
# 815  BINKSSV   1090
# 506  NWHIZNL   2680
# 888  QVXHFZN   4300
# 538  JWEUVDY   3500

# %% [markdown]
# Question 25

# %%
myDF[myDF['range'].between(250,350)]
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 506  5070    268     10            N   WHIZNL  LX38  [22$]  South America
# 538  5390    350     10            J   WEUVDY  CN38  [26$]           Asia
# 686  6870    333     10            G   BVONNE  KC21  [55$]      Australia
# 611  6120    333     11            H   YHTGCK  VS21  [15$]         Africa
# 808  8090    267     11            C   XTCQMQ  TW83  [20$]           Asia
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 542  5430    277     50            K   ATBSJF  GR36  [56$]         Africa
# 145  1460    302     50            S   DQIHRM  MF87  [86$]         Africa
# 260  2610    287     50            H   YFDAVD  PX32  [70$]  South America
# 306  3070    315     50            D   VFJBWF  DB57  [68$]         Europe
# 255  2560    322     50            P   ZZFRMM  RF30  [45$]     Antarctica
#
#        brand  total
# 506  NWHIZNL   2680
# 538  JWEUVDY   3500
# ...

# %% [markdown]
# Question 26

# %%
myDF[myDF['range'].between(250,350)].sort_values(by= ['range'],ascending=True)
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 57    580    250     19            K   EFXWGS  ZE30  [97$]      Australia
# 262  2630    250     12            O   ZZIXOA  LH11  [96$]         Europe
# 811  8120    251     49            D   QOWNHD  PD19  [86$]  South America
# 307  3080    251     26            Z   YCKPXV  CZ96  [52$]     Antarctica
# 276  2770    252     38            J   SKKOYK  UQ10  [82$]         Europe
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 833  8340    350     46            K   NCUWLM  FH32  [90$]  North America
# 645  6460    350     30            Q   LVDEAS  FG43  [93$]      Australia
# 538  5390    350     10            J   WEUVDY  CN38  [26$]           Asia
# 382  3830    350     14            M   FOIOWR  PW87  [12$]           Asia
# 738  7390    350     24            X      NaN  SY90  [83$]      Australia
#
#        brand  total
# 57   KEFXWGS   4750
# 262  OZZIXOA   3000
# ...

# %% [markdown]
# Question 27

# %%
myDF.loc[myDF.range.between(250,350),['id','value']]
# Out:
#        id  value
# 506  5070     10
# 538  5390     10
# 686  6870     10
# 611  6120     11
# 808  8090     11
# ..    ...    ...
# 542  5430     50
# 145  1460     50
# 260  2610     50
# 306  3070     50
# 255  2560     50
#
# [204 rows x 2 columns]

# %% [markdown]
# Question 28

# %%
myDF.loc[(myDF.range.between(250,350)) & (myDF['machine_type'] == 'H') ,['id','value', 'machine_type']]
# Out:
#        id  value machine type
# 611  6120     11            H
# 438  4390     11            H
# 302  3030     14            H
# 493  4940     16            H
# 525  5260     32            H
# 445  4460     32            H
# 620  6210     47            H
# 260  2610     50            H

# %% [markdown]
# Question 29

# %%
myDF[myDF["machine_type"].isin(['H','R','X'])]
# Out:
#        id  range  value machine type zip code Model   Cost      Continent  \
# 275  2760    247     10            H   PUTZZV  IQ87  [16$]           Asia
# 611  6120    333     11            H   YHTGCK  VS21  [15$]         Africa
# 497  4980    205     11            X   TKABSA  EA44  [84$]  North America
# 438  4390    262     11            H   JLHUNV  DU40  [26$]  North America
# 219  2200    375     13            R   ROTHUN  IZ32  [35$]     Antarctica
# ..    ...    ...    ...          ...      ...   ...    ...            ...
# 871  8720    104     49            H   AGKGDY  XZ79  [68$]         Europe
# 346  3470    180     49            R   QFLPSO  ZR39  [87$]      Australia
# 51    520    204     50            H   JGEDHI  TM26  [21$]  North America
# 260  2610    287     50            H   YFDAVD  PX32  [70$]  South America
# 125  1260    400     50            X   AHOATF  YS92  [90$]         Africa
#
#        brand  total
# 275  HPUTZZV   2470
# 611  HYHTGCK   3663
# ...

# %% [markdown]
# Question 30

# %%
myDF.dtypes
# Out:
# id               int64
# range            int64
# value            int64
# machine type    object
# zip code        object
# Model           object
# Cost            object
# Continent       object
# brand           object
# total            int64
# dtype: object

# %%
myDF.select_dtypes('int64')
# Out:
#        id  range  value  total
# 949  9500    137     10   1370
# 815  8160    109     10   1090
# 506  5070    268     10   2680
# 888  8890    430     10   4300
# 538  5390    350     10   3500
# ..    ...    ...    ...    ...
# 354  3550    160     50   8000
# 883  8840    385     50  19250
# 805  8060    136     50   6800
# 795  7960    448     50  22400
# 0      10    192     50   9600
#
# [948 rows x 4 columns]
